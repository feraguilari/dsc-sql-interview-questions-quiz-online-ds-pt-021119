# %% [markdown]
# # SQL Interview Questions  - Quiz
#
# ## Introduction
#
# In this lesson, we'll go through a short quiz containing the types of questions about SQL and relational databases that you can expect to see in an interview.
#
#
#
# ## SQL Interview Questions
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# what are the 5 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# 1. NULL. The value is a NULL value.<br>
#
# 2. INTEGER. The value is a signed integer, stored in 1, 2, 3, 4, 6, or 8 bytes depending on the magnitude of the value.<br>
#
# 3. REAL. The value is a floating point value, stored as an 8-byte IEEE floating point number.<br>
#
# 4. TEXT. The value is a text string, stored using the database encoding (UTF-8, UTF-16BE or UTF-16LE).<br>
#
# 5. BLOB. The value is a blob of data, stored exactly as it was input.<br>
#
# Boolean is stores as INTEGER with 0 or 1 value. Date and Time Datatype can be sroes as as TEXT, REAL, or INTEGER values.
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# 1. Primary key is the id for each row in each table.<br>
# 2. SQL foreign key constraints are used to enforce "exists" relationships between tables.
#
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# 1. One To Many relationship: One record in a table is linked to a single other record in another table.
# 2. One To One relationship: On record in a table is linked to seleveral records in another table.
# 3. Many To Many relationship: This is a more complex relationship since many records in one table are linked to many records in another table.
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# 1. INNER JOIN: Returns records that have matching values in both tables
# 2. LEFT JOIN: Returns all records from the left table, and the matched records from the right table
# 3. RIGHT JOIN: Returns all records from the right table, and the matched records from the left table
# 4. FULL JOIN: Returns all records when there is a match in either left or right table
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# * The GROUP BY statement is often used with aggregate functions (COUNT, MAX, MIN, SUM, AVG) to group the result-set by one or more columns.
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# * An Associative Entity must be used in order to handle a JOIN between two tables with a many-to-many relationship.
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
